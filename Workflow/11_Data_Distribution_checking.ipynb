# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv("pre_filtered_Score_matrix(merged_bbbp_toxicity_sas).csv")
data_1.head()
# Out:
#    Unnamed: 0                                             smiles  BBBP_Score  \
# 0           0  Cc1ccc([C@@H]2C(C(=O)c3cc(C)ccc3C)=C(O)C(=O)N2...    0.959117
# 1           1  C[C@@H]1CC=C[C@@H]2[C@@H]3O[C@]3(C)[C@H](C)[C@...    0.904171
# 2           2  COc1ccccc1/C=C1\SC(Nc2ccccc2)=C(C(=O)NC2CCN(C)...    0.911611
# 3           3        C#CCOc1c(I)cc([C@H]2NC(=O)c3ccccc3O2)cc1OCC    0.529800
# 4           4  C=C(C)CN1C(=O)N[C@@](CC)(C2CCN(C(=O)c3cc(C)nc4...    0.857044
#
#    transformed_SAScore     nr-ar  nr-ar-lbd    nr-ahr  nr-aromatase     nr-er  \
# 0             0.234951  0.081817   0.083164  0.079850      0.075258  0.078698
# 1             0.839875  0.070739   0.000823  0.078276      0.072571  0.070674
# 2             0.176104  0.083304   0.057318  0.060596      0.075316  0.076819
# 3             0.308177  0.083238   0.082843  0.077704      0.083292  0.082907
# 4             0.305703  0.083304   0.078816  0.071197      0.079916  0.083060
#
# ...

# %%
len(data_1)
# Out:
# 70244

# %%
data_2 = pd.read_csv("ranked_final_metrix_data.csv")
data_2
# Out:
#        Unnamed: 0                                             smiles  \
# 0           22562                COc1ccccc1N1CCN(C(=O)Nc2ccccc2C)CC1
# 1           22576                COc1ccccc1N1CCN(C(=O)Nc2ccccc2F)CC1
# 2           22583                COc1ccccc1NC(=O)N1CCN(Cc2ccccc2)CC1
# 3           23946                        COc1ccc(NC(=O)N2CCOCC2)cc1F
# 4           22868                 COc1ccccc1NC(=O)N1CCN(c2ccccc2)CC1
# ...           ...                                                ...
# 25092         862  O=C1[C@@H]2C[C@@H](CN2S(=O)(=O)Cc2ccccc2)Oc2cc...
# 25093       15057  O=C1[C@H]2Sc3[nH]c(=O)sc3C3(CCCC3)[C@@H]2C(=O)...
# 25094        8036  CCOC(=O)c1ccc(NC(=O)[C@H]2C[C@H]([C@@H](C)O)N[...
# 25095       19904  COCCN1C(=O)N=C(O)[C@@]2(Cc3ccccc3N3CCN(Cc4cccc...
# 25096       19812  COCCN1C(=O)N=C(O)[C@]2(Cc3ccccc3N3CCN(Cc4ccccc...
#
#        BBBP_Score  transformed_SAScore     nr-ar  nr-ar-lbd    nr-ahr  \
# ...

# %%
len(data_2)
# Out:
# 25097

# %%
data_1_bbbp = data_1["BBBP_Score"]
#data_1_bbbp
bbbp_df_1 = pd.DataFrame({"BBBP_Score":data_1_bbbp, "Dataset": "Dataset1"})
bbbp_df_1
# Out:
#        BBBP_Score   Dataset
# 0        0.959117  Dataset1
# 1        0.904171  Dataset1
# 2        0.911611  Dataset1
# 3        0.529800  Dataset1
# 4        0.857044  Dataset1
# ...           ...       ...
# 70239    0.985979  Dataset1
# 70240    0.913541  Dataset1
# 70241    0.917182  Dataset1
# 70242    0.655888  Dataset1
# 70243    0.655888  Dataset1
#
# [70244 rows x 2 columns]

# %%
data_2_bbbp = data_2["BBBP_Score"]
bbbp_df_2 = pd.DataFrame({"BBBP_Score":data_2_bbbp, "Dataset": "Dataset2"})
bbbp_df_2
# Out:
#        BBBP_Score   Dataset
# 0        0.974694  Dataset2
# 1        0.975394  Dataset2
# 2        0.970438  Dataset2
# 3        0.951761  Dataset2
# 4        0.969156  Dataset2
# ...           ...       ...
# 25092    0.506786  Dataset2
# 25093    0.639423  Dataset2
# 25094    0.607715  Dataset2
# 25095    0.504856  Dataset2
# 25096    0.504856  Dataset2
#
# [25097 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터프레임 병합
bbbp_df = pd.concat([bbbp_df_1, bbbp_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=bbbp_df, x='BBBP_Score', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('BBBP Score Distribution')
plt.xlabel('BBBP Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("BBBP_distribution_image.png")
plt.show()

# %%
data_1_sas = data_1["transformed_SAScore"]
sas_df_1 = pd.DataFrame({"transformed_SAScore":data_1_sas, "Dataset": "Dataset1"})

data_2_sas = data_2["transformed_SAScore"]
sas_df_2 = pd.DataFrame({"transformed_SAScore":data_2_sas, "Dataset": "Dataset2"})

# 데이터프레임 병합
sas_df = pd.concat([sas_df_1, sas_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=sas_df, x='transformed_SAScore', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('SAScore Distribution')
plt.xlabel('SAScore')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("SAS_distribution_image.png")
plt.show()

# %%
data_1_nr_ar = data_1["nr-ar"]
nr_ar_df_1 = pd.DataFrame({"nr-ar":data_1_nr_ar, "Dataset": "Dataset1"})

data_2_nr_ar = data_2["nr-ar"]
nr_ar_df_2 = pd.DataFrame({"nr-ar":data_2_nr_ar, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_ar_df = pd.concat([nr_ar_df_1, nr_ar_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_ar_df, x='nr-ar', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-ar Distribution')
plt.xlabel('nr-ar Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-ar_toxicity_distribution_image.png")
plt.show()

# %%
data_1_nr_ar_lbd = data_1["nr-ar-lbd"]
nr_ar_lbd_df_1 = pd.DataFrame({"nr-ar-lbd":data_1_nr_ar_lbd, "Dataset": "Dataset1"})

data_2_nr_ar_lbd = data_2["nr-ar-lbd"]
nr_ar_lbd_df_2 = pd.DataFrame({"nr-ar-lbd":data_2_nr_ar_lbd, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_ar_lbd_df = pd.concat([nr_ar_lbd_df_1, nr_ar_lbd_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_ar_lbd_df, x='nr-ar-lbd', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-ar-lbd Distribution')
plt.xlabel('nr-ar-lbd Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-ar-lbd_toxicity_distribution_image.png")
plt.show()

# %%
data_1_nr_ahr = data_1["nr-ahr"]
nr_ahr_df_1 = pd.DataFrame({"nr-ahr":data_1_nr_ahr, "Dataset": "Dataset1"})

data_2_nr_ahr = data_2["nr-ahr"]
nr_ahr_df_2 = pd.DataFrame({"nr-ahr":data_2_nr_ahr, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_ahr_df = pd.concat([nr_ahr_df_1, nr_ahr_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_ahr_df, x='nr-ahr', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-ahr Distribution')
plt.xlabel('nr-ahr Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-ahr_toxicity_distribution_image.png")
plt.show()

# %%
data_1_nr_aromatase = data_1["nr-aromatase"]
nr_aromatase_df_1 = pd.DataFrame({"nr-aromatase":data_1_nr_aromatase, "Dataset": "Dataset1"})

data_2_nr_aromatase = data_2["nr-aromatase"]
nr_aromatase_df_2 = pd.DataFrame({"nr-aromatase":data_2_nr_aromatase, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_aromatase_df = pd.concat([nr_aromatase_df_1, nr_aromatase_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_aromatase_df, x='nr-aromatase', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-aromatase Distribution')
plt.xlabel('nr-aromatase Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-aromatase_toxicity_distribution_image.png")
plt.show()

# %%
data_1_nr_er = data_1["nr-er"]
nr_er_df_1 = pd.DataFrame({"nr-er":data_1_nr_er, "Dataset": "Dataset1"})

data_2_nr_er = data_2["nr-er"]
nr_er_df_2 = pd.DataFrame({"nr-er":data_2_nr_er, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_er_df = pd.concat([nr_er_df_1, nr_er_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_er_df, x='nr-er', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-er Distribution')
plt.xlabel('nr-er Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-er_toxicity_distribution_image.png")
plt.show()

# %%
data_1_nr_er_lbd = data_1["nr-er-lbd"]
nr_er_lbd_df_1 = pd.DataFrame({"nr-er-lbd":data_1_nr_er_lbd, "Dataset": "Dataset1"})

data_2_nr_er_lbd = data_2["nr-er-lbd"]
nr_er_lbd_df_2 = pd.DataFrame({"nr-er-lbd":data_2_nr_er_lbd, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_er_lbd_df = pd.concat([nr_er_lbd_df_1, nr_er_lbd_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_er_lbd_df, x='nr-er-lbd', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-er-lbd Distribution')
plt.xlabel('nr-er-lbd Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-er-lbd_toxicity_distribution_image.png")
plt.show()

# %%
data_1_nr_ppar_gamma = data_1["nr-ppar-gamma"]
nr_ppar_gamma_df_1 = pd.DataFrame({"nr-ppar-gamma":data_1_nr_ppar_gamma, "Dataset": "Dataset1"})

data_2_nr_ppar_gamma = data_2["nr-ppar-gamma"]
nr_ppar_gamma_df_2 = pd.DataFrame({"nr-ppar-gamma":data_2_nr_ppar_gamma, "Dataset": "Dataset2"})

# 데이터프레임 병합
nr_ppar_gamma_df = pd.concat([nr_ppar_gamma_df_1, nr_ppar_gamma_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=nr_ppar_gamma_df, x='nr-ppar-gamma', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('nr-ppar-gamma Distribution')
plt.xlabel('nr-ppar-gamma Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("nr-ppar-gamma_toxicity_distribution_image.png")
plt.show()

# %%
data_1_sr_are = data_1["sr-are"]
sr_are_df_1 = pd.DataFrame({"sr-are":data_1_sr_are, "Dataset": "Dataset1"})

data_2_sr_are = data_2["sr-are"]
sr_are_df_2 = pd.DataFrame({"sr-are":data_2_sr_are, "Dataset": "Dataset2"})

# 데이터프레임 병합
sr_are_df = pd.concat([sr_are_df_1, sr_are_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=sr_are_df, x='sr-are', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('sr-are Distribution')
plt.xlabel('sr-are Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("sr-are_toxicity_distribution_image.png")
plt.show()

# %%
data_1_sr_atad5 = data_1["sr-atad5"]
sr_atad5_df_1 = pd.DataFrame({"sr-atad5":data_1_sr_atad5, "Dataset": "Dataset1"})

data_2_sr_atad5 = data_2["sr-atad5"]
sr_atad5_df_2 = pd.DataFrame({"sr-atad5":data_2_sr_atad5, "Dataset": "Dataset2"})

# 데이터프레임 병합
sr_atad5_df = pd.concat([sr_atad5_df_1, sr_atad5_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=sr_atad5_df, x='sr-atad5', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('sr-atad5 Distribution')
plt.xlabel('sr-atad5 Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("sr-atad5_toxicity_distribution_image.png")
plt.show()

# %%
data_1_sr_hse = data_1["sr-hse"]
sr_hse_df_1 = pd.DataFrame({"sr-hse":data_1_sr_hse, "Dataset": "Dataset1"})

data_2_sr_hse = data_2["sr-hse"]
sr_hse_df_2 = pd.DataFrame({"sr-hse":data_2_sr_hse, "Dataset": "Dataset2"})

# 데이터프레임 병합
sr_hse_df = pd.concat([sr_hse_df_1, sr_hse_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=sr_hse_df, x='sr-hse', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('sr-hse Distribution')
plt.xlabel('sr-hse Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("sr-hse_toxicity_distribution_image.png")
plt.show()

# %%
data_1_sr_mmp = data_1["sr-mmp"]
sr_mmp_df_1 = pd.DataFrame({"sr-mmp":data_1_sr_mmp, "Dataset": "Dataset1"})

data_2_sr_mmp = data_2["sr-mmp"]
sr_mmp_df_2 = pd.DataFrame({"sr-mmp":data_2_sr_mmp, "Dataset": "Dataset2"})

# 데이터프레임 병합
sr_mmp_df = pd.concat([sr_mmp_df_1, sr_mmp_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=sr_mmp_df, x='sr-mmp', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('sr-mmp Distribution')
plt.xlabel('sr-mmp Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("sr-mmp_toxicity_distribution_image.png")
plt.show()

# %%
data_1_sr_p53 = data_1["sr-p53"]
sr_p53_df_1 = pd.DataFrame({"sr-p53":data_1_sr_p53, "Dataset": "Dataset1"})

data_2_sr_p53 = data_2["sr-p53"]
sr_p53_df_2 = pd.DataFrame({"sr-p53":data_2_sr_p53, "Dataset": "Dataset2"})

# 데이터프레임 병합
sr_p53_df = pd.concat([sr_p53_df_1, sr_p53_df_2])

# 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(data=sr_p53_df, x='sr-p53', hue='Dataset', stat='count', common_norm=False, kde=True, multiple="stack")
plt.title('sr-p53 Distribution')
plt.xlabel('sr-p53 Score')
plt.ylabel('Count')
plt.legend(loc='upper left', labels=["Filtered Dataset", "Not Filtered Dataset"])
plt.savefig("sr-p53_toxicity_distribution_image.png")
plt.show()

# %% [markdown]
# ### top10 와 ZN27 비교 그래프

# %%
import pandas as pd

# %%
total_data = pd.read_csv("rank_top_10_molecules_with_ZN27.csv", index_col=False)
total_data.head()
# Out:
#                                 smiles  BBBP_Score  transformed_SAScore  \
# 0  COc1ccccc1N1CCN(C(=O)Nc2ccccc2C)CC1    0.974694             0.020517
# 1  COc1ccccc1N1CCN(C(=O)Nc2ccccc2F)CC1    0.975394             0.027805
# 2  COc1ccccc1NC(=O)N1CCN(Cc2ccccc2)CC1    0.970438             0.005800
# 3          COc1ccc(NC(=O)N2CCOCC2)cc1F    0.951761             0.035180
# 4   COc1ccccc1NC(=O)N1CCN(c2ccccc2)CC1    0.969156             0.005323
#
#       nr-ar  nr-ar-lbd    nr-ahr  nr-aromatase     nr-er  nr-er-lbd  \
# 0  0.079317   0.082571  0.078800      0.069113  0.070744   0.083292
# 1  0.080156   0.083060  0.079669      0.071584  0.073692   0.083218
# 2  0.082354   0.083083  0.076208      0.079669  0.070531   0.083132
# 3  0.080106   0.083305  0.080994      0.081588  0.081984   0.082394
# 4  0.082736   0.082926  0.074853      0.075315  0.069438   0.083288
#
#    nr-ppar-gamma    sr-are  sr-atad5    sr-hse    sr-mmp    sr-p53     total  \
# ...

# %%
total_data.index = list(range(1, 12))

# %%
total_data
# Out:
#                                                smiles  BBBP_Score  \
# 1                 COc1ccccc1N1CCN(C(=O)Nc2ccccc2C)CC1    0.974694
# 2                 COc1ccccc1N1CCN(C(=O)Nc2ccccc2F)CC1    0.975394
# 3                 COc1ccccc1NC(=O)N1CCN(Cc2ccccc2)CC1    0.970438
# 4                         COc1ccc(NC(=O)N2CCOCC2)cc1F    0.951761
# 5                  COc1ccccc1NC(=O)N1CCN(c2ccccc2)CC1    0.969156
# 6                          COc1cccc(NC(=O)N2CCOCC2)c1    0.977305
# 7             COc1ccc(NC(=O)N2CCN(c3ccc(F)cc3)CC2)cc1    0.959994
# 8                 CCOc1ccccc1N1CCN(C(=O)Nc2ccccc2)CC1    0.977472
# 9                 COc1ccccc1NC(=O)N1CCN(c2ccccc2F)CC1    0.975394
# 10                       COc1ccc(NC(=O)N2CCOCC2)cc1Cl    0.936357
# 11  COc1ccc([C@@H]2CCCN2C(=O)Nc2cc(C(F)(F)F)ccc2N2...    0.976869
#
#     transformed_SAScore     nr-ar  nr-ar-lbd    nr-ahr  nr-aromatase  \
# 1              0.020517  0.079317   0.082571  0.078800      0.069113
# ...

# %%
import matplotlib.pyplot as plt

index = list(range(1,12))  # 인덱스 번호 1부터 11까지
bbbp_scores = total_data["BBBP_Score"]

# scatter plot 생성
plt.scatter(index[:10], bbbp_scores[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], bbbp_scores[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], bbbp_scores[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('BBBP Score')
plt.title('Scatter Plot of BBBP Scores')
plt.legend()

# 그래프 출력
plt.savefig("comparing_BBBP_Score_with_ZN27_image.png")
plt.show()

# %%
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
SAScore = total_data["transformed_SAScore"]

# scatter plot 생성
plt.scatter(index[:10], SAScore[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], SAScore[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], SAScore[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('SAScore')
plt.title('Scatter Plot of SAScores')
plt.legend()

# 그래프 출력
plt.savefig("comparing_SAScore_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_ar = total_data["nr-ar"]

# scatter plot 생성
plt.scatter(index[:10], nr_ar[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_ar[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_ar[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_ar')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_ar_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_ar_lbd = total_data["nr-ar-lbd"]

# scatter plot 생성
plt.scatter(index[:10], nr_ar_lbd[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_ar_lbd[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_ar_lbd[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_ar_lbd')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_ar_lbd_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_ahr = total_data["nr-ahr"]

# scatter plot 생성
plt.scatter(index[:10], nr_ahr[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_ahr[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_ahr[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_ahr')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_ahr_lbd_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_aromatase = total_data["nr-aromatase"]

# scatter plot 생성
plt.scatter(index[:10], nr_aromatase[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_aromatase[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_aromatase[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_aromatase')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_aromatase_lbd_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_er = total_data["nr-er"]

# scatter plot 생성
plt.scatter(index[:10], nr_er[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_er[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_er[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_er')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_er_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_er_lbd = total_data["nr-er-lbd"]

# scatter plot 생성
plt.scatter(index[:10], nr_er_lbd[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_er_lbd[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_er_lbd[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_er_lbd')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_er_lbd_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
nr_ppar_gamma = total_data["nr-ppar-gamma"]

# scatter plot 생성
plt.scatter(index[:10], nr_ppar_gamma[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], nr_ppar_gamma[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], nr_ppar_gamma[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('nr_ppar_gamma')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_nr_ppar_gamma_lbd_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
sr_are = total_data["sr-are"]

# scatter plot 생성
plt.scatter(index[:10], sr_are[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], sr_are[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], sr_are[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('sr_are')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_sr_are_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
sr_atad5 = total_data["sr-atad5"]

# scatter plot 생성
plt.scatter(index[:10], sr_atad5[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], sr_atad5[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], sr_atad5[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('sr_atad5')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_sr_atad5_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
sr_hse = total_data["sr-hse"]

# scatter plot 생성
plt.scatter(index[:10], sr_hse[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], sr_hse[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], sr_hse[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('sr_hse')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_sr_hse_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
sr_mmp = total_data["sr-mmp"]

# scatter plot 생성
plt.scatter(index[:10], sr_mmp[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], sr_mmp[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], sr_mmp[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('sr_mmp')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_sr_mmp_with_ZN27_image.png")
plt.show()

# %%
import matplotlib.pyplot as plt
index = list(range(1,12))  # 인덱스 번호 1부터 11까지
sr_p53 = total_data["sr-p53"]

# scatter plot 생성
plt.scatter(index[:10], sr_p53[:10], color='blue', label='1-10 rank', marker='o')  # 0번부터 10번까지 파란색 동그라미
plt.scatter(index[10], sr_p53[11], color='red', label='ZN27', marker='o')  # 11번 빨간색 동그라미

# 11번 인덱스에 ZN27 텍스트 표시
plt.text(index[10], sr_p53[11], 'ZN27', fontsize=12, color='red', horizontalalignment='right')

# x 축 간격 설정
plt.xticks(index)

# 그래프 꾸미기
plt.xlabel('Rank')
plt.ylabel('sr_p53')
plt.title('Scatter Plot of Toxicity')
plt.legend()

# 그래프 출력
plt.savefig("comparing_sr_p53_with_ZN27_image.png")
plt.show()
